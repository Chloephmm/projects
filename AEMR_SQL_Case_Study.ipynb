# %% [markdown]
# <center><h1 style="color:#D4AF37"> AEMR Data Analysis </h1>

# %% [markdown]
# <h1 style="color:#D4AF37"> What's the Business Problem? 💰</h1>
#
# The American Energy Market Regulator (AEMR) is responsible for looking after the
# United States of America’s domestic energy network. The regulator’s responsibility is to
# ensure that America’s energy network remains reliable with minimal disruptions, which
# are known as outages.
#
# There are four key types of outages:
#
# ● Consequential
#
# ● Forced
#
# ● Opportunistic
#
# ● Planned
#
# Recently, the AEMR management team has been increasingly aware of a large number
# of energy providers that submitted outages over the 2016 and 2017 calendar years. The
# management team has expressed a desire to have the following two areas of concern
# addressed:
#
# <b> A) Energy Stability and Market Outages
#     <p>
# B) Energy Losses and Market Reliability </b>

# %% [markdown]
# <h3 style="color:#D4AF37">  SQLite Refresher ⚙️ </h3>

# %%
# %%capture
# !pip install ipython-sql sqlalchemy
import sqlalchemy
sqlalchemy.create_engine("sqlite:///AEMR.db")
# %load_ext sql
# %sql sqlite:///AEMR.db

# %%
# %%js
# require(['notebook/js/codecell'], function (codecell) {
#     codecell.CodeCell.options_default.highlight_modes['magic_text/x-mssql'] = { 'reg': [/%?%sql/] };
#     Jupyter.notebook.events.one('kernel_ready.Kernel', function () {
#         Jupyter.notebook.get_cells().map(function (cell) {
#             if (cell.cell_type == 'code') { cell.auto_highlight(); }
#         });
#     });
# });

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part I. Energy Stability & Market Outages ⚡ </h3>
#
# Energy stability is one of the key themes the AEMR management team cares about. To ensure energy security and reliability, AEMR needs to understand the following:
# <p>
# <b>
#
# <li> What are the most common outage types and how long do they tend to last?
# <li> How frequently do the outages occur?
# <li> Are there any energy providers which have more outages than their peers which may be indicative of being unreliable?
#
# <p>
#
# <u style="color:Maroon"> Throughout the entire case study, we are interested ONLY in the Outages where Status = Approved.</u>

# %% [markdown]
# <h3 style="color:#D4AF37"> 1. </h3>
#
# <b> A SQL Statement to `COUNT` the number of valid (i.e. `Status = Approved`) Outage Events sorted by their respective `Outage_Reason` (i.e. `Forced`, `Consequential`, `Scheduled`, `Opportunistic`) over the 2016 & 2017 Periods. </b>
#
# Do we notice anything regarding the trends for specific Outages over the 2016 / 2017 Period?
# - Highest total number outages: 1264 (in 2016) and 1622 (in 2017) for Outage Reason: Forced.

# %%
# %%sql
# SELECT COUNT(*) AS Total_Number_Outages,
# Outage_Reason,
# Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Outage_Reason, Year
# ;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(181, 'Consequential', 2016),
#  (127, 'Consequential', 2017),
#  (1264, 'Forced', 2016),
#  (1622, 'Forced', 2017),
#  (106, 'Opportunistic Maintenance (Planned)', 2016),
#  (102, 'Opportunistic Maintenance (Planned)', 2017),
#  (380, 'Scheduled (Planned)', 2016),
#  (320, 'Scheduled (Planned)', 2017)]

# %% [markdown]
# <h3 style="color:#D4AF37"> 2. </h3>

# %% [markdown]
# <b> i) A SQL Statement showing the `Total` of all Outage Types (Forced, Consequential, Scheduled, Opportunistic) where the `Status = Approved`, that occurred for both 2016 and 2017, grouped by `Year` and `Month`.  per month (i.e. 1 – 12). Order by `Year`, `Month`, `Total_Number_Outages` in Descending Order.
#
#
# ii) Building on the query write in i), group the results by `Outage Type`, `Year` and `Month`. This is so we can identify whether there is any outage type specifically increasing on a monthly basis when comparing 2016 to 2017. </b>

# %%
# %%sql
# SELECT
# Year,
# Month,
# COUNT (*) AS Total_Number_Outages,
# Outage_Reason
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Outage_Reason, Year, Month
# ORDER BY Year, Month,Total_Number_Outages DESC
# ;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1, 134, 'Forced'),
#  (2016, 1, 24, 'Consequential'),
#  (2016, 1, 24, 'Scheduled (Planned)'),
#  (2016, 1, 9, 'Opportunistic Maintenance (Planned)'),
#  (2016, 2, 149, 'Forced'),
#  (2016, 2, 43, 'Scheduled (Planned)'),
#  (2016, 2, 23, 'Consequential'),
#  (2016, 2, 12, 'Opportunistic Maintenance (Planned)'),
#  (2016, 3, 94, 'Forced'),
#  (2016, 3, 21, 'Scheduled (Planned)'),
#  (2016, 3, 14, 'Opportunistic Maintenance (Planned)'),
#  (2016, 3, 7, 'Consequential'),
#  (2016, 4, 86, 'Forced'),
#  (2016, 4, 45, 'Scheduled (Planned)'),
#  (2016, 4, 3, 'Opportunistic Maintenance (Planned)'),
#  (2016, 5, 101, 'Forced'),
#  (2016, 5, 36, 'Consequential'),
#  (2016, 5, 33, 'Scheduled (Planned)'),
#  (2016, 5, 4, 'Opportunistic Maintenance (Planned)'),
#  (2016, 6, 112, 'Forced'),
#  (2016, 6, 30, 'Scheduled (Planned)'),
#  (2016, 6, 14, 'Opportunistic Maintenance (Planned)'),
#  (2016, 6, 12, 'Consequential'),
#  (2016, 7, 80, 'Forced'),
#  (2016, 7, 31, 'Scheduled (Planned)'),
#  (2016, 7, 23, 'Consequential'),
#  (2016, 7, 13, 'Opportunistic Maintenance (Planned)'),
#  (2016, 8, 152, 'Forced'),
#  (2016, 8, 29, 'Scheduled (Planned)'),
#  (2016, 8, 7, 'Opportunistic Maintenance (Planned)'),
#  (2016, 8, 6, 'Consequential'),
#  (2016, 9, 96, 'Forced'),
#  (2016, 9, 16, 'Scheduled (Planned)'),
#  (2016, 9, 11, 'Opportunistic Maintenance (Planned)'),
#  (2016, 9, 1, 'Consequential'),
#  (2016, 10, 67, 'Forced'),
#  (2016, 10, 37, 'Scheduled (Planned)'),
#  (2016, 10, 15, 'Consequential'),
#  (2016, 10, 5, 'Opportunistic Maintenance (Planned)'),
#  (2016, 11, 127, 'Forced'),
#  (2016, 11, 41, 'Scheduled (Planned)'),
#  (2016, 11, 25, 'Consequential'),
#  (2016, 11, 7, 'Opportunistic Maintenance (Planned)'),
#  (2016, 12, 66, 'Forced'),
#  (2016, 12, 30, 'Scheduled (Planned)'),
#  (2016, 12, 9, 'Consequential'),
#  (2016, 12, 7, 'Opportunistic Maintenance (Planned)'),
#  (2017, 1, 70, 'Forced'),
#  (2017, 1, 12, 'Consequential'),
#  (2017, 1, 12, 'Scheduled (Planned)'),
#  (2017, 1, 9, 'Opportunistic Maintenance (Planned)'),
#  (2017, 2, 97, 'Forced'),
#  (2017, 2, 27, 'Consequential'),
#  (2017, 2, 20, 'Scheduled (Planned)'),
#  (2017, 2, 6, 'Opportunistic Maintenance (Planned)'),
#  (2017, 3, 53, 'Forced'),
#  (2017, 3, 30, 'Scheduled (Planned)'),
#  (2017, 3, 19, 'Consequential'),
#  (2017, 3, 7, 'Opportunistic Maintenance (Planned)'),
#  (2017, 4, 73, 'Forced'),
#  (2017, 4, 34, 'Scheduled (Planned)'),
#  (2017, 4, 12, 'Consequential'),
#  (2017, 4, 8, 'Opportunistic Maintenance (Planned)'),
#  (2017, 5, 105, 'Forced'),
#  (2017, 5, 47, 'Scheduled (Planned)'),
#  (2017, 5, 9, 'Opportunistic Maintenance (Planned)'),
#  (2017, 5, 5, 'Consequential'),
#  (2017, 6, 172, 'Forced'),
#  (2017, 6, 17, 'Scheduled (Planned)'),
#  (2017, 6, 8, 'Consequential'),
#  (2017, 6, 7, 'Opportunistic Maintenance (Planned)'),
#  (2017, 7, 182, 'Forced'),
#  (2017, 7, 22, 'Scheduled (Planned)'),
#  (2017, 7, 5, 'Opportunistic Maintenance (Planned)'),
#  (2017, 7, 1, 'Consequential'),
#  (2017, 8, 170, 'Forced'),
#  (2017, 8, 23, 'Scheduled (Planned)'),
#  (2017, 8, 14, 'Opportunistic Maintenance (Planned)'),
#  (2017, 8, 2, 'Consequential'),
#  (2017, 9, 137, 'Forced'),
#  (2017, 9, 18, 'Scheduled (Planned)'),
#  (2017, 9, 10, 'Consequential'),
#  (2017, 9, 7, 'Opportunistic Maintenance (Planned)'),
#  (2017, 10, 207, 'Forced'),
#  (2017, 10, 50, 'Scheduled (Planned)'),
#  (2017, 10, 11, 'Consequential'),
#  (2017, 10, 8, 'Opportunistic Maintenance (Planned)'),
#  (2017, 11, 145, 'Forced'),
#  (2017, 11, 27, 'Scheduled (Planned)'),
#  (2017, 11, 16, 'Opportunistic Maintenance (Planned)'),
#  (2017, 11, 9, 'Consequential'),
#  (2017, 12, 211, 'Forced'),
#  (2017, 12, 20, 'Scheduled (Planned)'),
#  (2017, 12, 11, 'Consequential'),
#  (2017, 12, 6, 'Opportunistic Maintenance (Planned)')]

# %% [markdown]
# We've now identified a specific outage type is rapidly increasing from 2016 to 2017. However, frequency is just one aspect we care about. We also care about the <b> `duration` </b> of our ouatges.
#
# In other words, if an outage is very short, we aren't as concerned. However, if the outage is very long, this then has the risk of threatening our energy supplies. We want to identify the problematic energy providers here. This leads us to our next question below.

# %% [markdown]
# <h3 style="color:#D4AF37"> 3. </h3>

# %% [markdown]
# <b>A SQL statement that calculates 1) The `Total_Number_Outage_Events` and 2) The <b> `Average Duration`</b> in <u>DAYS</u> for each `Participant Code` and `Outage Type` over the 2016 and 2017 Period where the `Status = Approved`.
# Order by `Total_Number_Outage_Events` in Descending Order, `Reason` and `Year`.

# %%
# %%sql
# SELECT
# Participant_Code,
# Outage_Reason,
# Year,
# COUNT(*) AS Total_Number_Outage_Events,
# ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Year, Month, Participant_Code
# ORDER BY Total_Number_Outage_Events DESC
# ;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 125, 0.14),
#  ('GW', 'Forced', 2016, 110, 0.61),
#  ('AURICON', 'Forced', 2017, 95, 0.14),
#  ('AURICON', 'Forced', 2017, 86, 0.24),
#  ('GW', 'Forced', 2017, 67, 0.41),
#  ('AURICON', 'Forced', 2016, 63, 0.19),
#  ('GW', 'Forced', 2016, 55, 0.4),
#  ('GW', 'Forced', 2016, 52, 0.44),
#  ('AURICON', 'Forced', 2017, 52, 0.25),
#  ('GW', 'Forced', 2017, 50, 0.03),
#  ('AURICON', 'Forced', 2017, 45, 0.12),
#  ('AURICON', 'Forced', 2016, 42, 0.04),
#  ('MELK', 'Forced', 2016, 42, 0.92),
#  ('MELK', 'Forced', 2017, 41, 1.94),
#  ('PMC', 'Scheduled (Planned)', 2016, 39, 0.29),
#  ('MELK', 'Forced', 2016, 38, 2.6),
#  ('AUXC', 'Forced', 2016, 38, 0.0),
#  ('GW', 'Consequential', 2016, 35, 2.52),
#  ('MELK', 'Forced', 2016, 34, 1.93),
#  ('AURICON', 'Forced', 2016, 33, 0.13),
#  ('PUG', 'Forced', 2017, 33, 0.02),
#  ('AURICON', 'Forced', 2016, 32, 0.19),
#  ('AURICON', 'Forced', 2016, 32, 0.3),
#  ('TRMOS', 'Forced', 2017, 32, 0.07),
#  ('TRMOS', 'Forced', 2017, 31, 0.29),
#  ('AUXC', 'Forced', 2017, 31, 0.0),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 30, 1.02),
#  ('GW', 'Forced', 2016, 30, 1.15),
#  ('AURICON', 'Forced', 2017, 30, 0.15),
#  ('AUXC', 'Forced', 2016, 29, 0.07),
#  ('MELK', 'Forced', 2016, 29, 1.43),
#  ('AURICON', 'Forced', 2017, 29, 0.35),
#  ('AURICON', 'Forced', 2017, 29, 0.25),
#  ('MELK', 'Forced', 2017, 29, 1.76),
#  ('MELK', 'Forced', 2017, 29, 3.36),
#  ('MELK', 'Forced', 2017, 28, 1.93),
#  ('AURICON', 'Forced', 2017, 28, 0.07),
#  ('MELK', 'Forced', 2017, 28, 11.67),
#  ('AUXC', 'Consequential', 2016, 27, 0.25),
#  ('MELK', 'Forced', 2017, 27, 1.6),
#  ('MELK', 'Forced', 2016, 26, 0.99),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 26, 0.98),
#  ('MELK', 'Forced', 2016, 24, 3.42),
#  ('GW', 'Forced', 2016, 24, 0.74),
#  ('AURICON', 'Forced', 2017, 24, 0.22),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 24, 0.36),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.39),
#  ('GW', 'Forced', 2017, 23, 1.1),
#  ('AURICON', 'Forced', 2016, 22, 1.72),
#  ('GW', 'Forced', 2016, 22, 0.85),
#  ('AUXC', 'Forced', 2016, 21, 0.0),
#  ('MELK', 'Forced', 2016, 21, 1.03),
#  ('GW', 'Forced', 2017, 21, 2.85),
#  ('PUG', 'Forced', 2017, 21, 0.08),
#  ('TRMOS', 'Forced', 2016, 20, 0.07),
#  ('AURICON', 'Forced', 2017, 20, 0.08),
#  ('TRMOS', 'Forced', 2017, 20, 1.59),
#  ('PUG', 'Forced', 2017, 20, 0.91),
#  ('TRMOS', 'Forced', 2017, 20, 0.05),
#  ('GW', 'Forced', 2016, 19, 0.11),
#  ('PJRH', 'Forced', 2016, 19, 2.89),
#  ('AUXC', 'Forced', 2016, 19, 0.0),
#  ('AUXC', 'Forced', 2017, 19, 0.0),
#  ('PUG', 'Forced', 2017, 19, 0.52),
#  ('KORL', 'Forced', 2017, 19, 0.77),
#  ('PJRH', 'Forced', 2016, 18, 0.37),
#  ('AURICON', 'Forced', 2016, 18, 0.44),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 18, 0.44),
#  ('GW', 'Consequential', 2017, 18, 0.52),
#  ('PJRH', 'Forced', 2016, 17, 0.21),
#  ('AUXC', 'Forced', 2016, 17, 0.0),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 17, 1.52),
#  ('MELK', 'Forced', 2017, 17, 2.63),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 16, 3.1),
#  ('MELK', 'Forced', 2016, 16, 1.13),
#  ('MELK', 'Forced', 2017, 16, 2.14),
#  ('GW', 'Consequential', 2017, 16, 4.86),
#  ('GW', 'Forced', 2017, 16, 0.4),
#  ('TRMOS', 'Forced', 2017, 16, 0.06),
#  ('PMC', 'Forced', 2016, 15, 0.04),
#  ('AURICON', 'Forced', 2016, 15, 1.19),
#  ('PJRH', 'Forced', 2016, 15, 3.25),
#  ('GW', 'Forced', 2017, 15, 1.51),
#  ('MELK', 'Forced', 2017, 15, 3.31),
#  ('MELK', 'Forced', 2017, 15, 3.74),
#  ('GW', 'Forced', 2017, 15, 4.21),
#  ('PMC', 'Forced', 2017, 15, 0.06),
#  ('TRMOS', 'Forced', 2017, 15, 2.09),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 15, 0.29),
#  ('COLLGAR', 'Consequential', 2016, 14, 2.13),
#  ('AUXC', 'Forced', 2017, 14, 0.03),
#  ('AURICON', 'Consequential', 2017, 14, 0.53),
#  ('PJRH', 'Forced', 2017, 14, 1.07),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 14, 0.08),
#  ('GW', 'Forced', 2017, 14, 0.43),
#  ('COLLGAR', 'Forced', 2017, 14, 5.44),
#  ('TRMOS', 'Forced', 2016, 13, 0.2),
#  ('AUXC', 'Forced', 2016, 13, 0.0),
#  ('ENRG', 'Scheduled (Planned)', 2016, 13, 3.23),
#  ('PUG', 'Forced', 2017, 13, 0.01),
#  ('TRMOS', 'Forced', 2017, 13, 0.06),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 13, 2.36),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.04),
#  ('AUXC', 'Forced', 2017, 13, 0.02),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 0.22),
#  ('AUXC', 'Forced', 2016, 12, 0.0),
#  ('AURICON', 'Forced', 2016, 12, 0.21),
#  ('MELK', 'Forced', 2017, 12, 3.85),
#  ('KORL', 'Forced', 2017, 12, 2.69),
#  ('MELK', 'Forced', 2016, 11, 5.45),
#  ('AUXC', 'Forced', 2016, 11, 0.97),
#  ('MUND', 'Forced', 2016, 11, 0.12),
#  ('AURICON', 'Forced', 2016, 11, 0.34),
#  ('GW', 'Forced', 2016, 11, 1.02),
#  ('PJRH', 'Forced', 2017, 11, 0.33),
#  ('KORL', 'Consequential', 2017, 11, 0.34),
#  ('AUXC', 'Forced', 2017, 11, 0.0),
#  ('PUG', 'Forced', 2017, 11, 0.02),
#  ('GW', 'Forced', 2017, 11, 1.21),
#  ('GW', 'Forced', 2016, 10, 0.14),
#  ('AURICON', 'Forced', 2016, 10, 0.43),
#  ('TSLA_MGT', 'Consequential', 2016, 10, 0.4),
#  ('MELK', 'Forced', 2016, 10, 3.87),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 10, 1.61),
#  ('PMC', 'Consequential', 2017, 10, 0.05),
#  ('KORL', 'Forced', 2017, 10, 3.94),
#  ('MUND', 'Forced', 2017, 10, 0.28),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 10, 1.72),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.49),
#  ('PMC', 'Consequential', 2017, 10, 0.21),
#  ('PUG', 'Forced', 2017, 10, 0.1),
#  ('ENRG', 'Consequential', 2016, 9, 1.28),
#  ('KORL', 'Forced', 2016, 9, 1.13),
#  ('KORL', 'Forced', 2016, 9, 0.41),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 9, 0.35),
#  ('TSLA_MGT', 'Forced', 2016, 9, 0.62),
#  ('PJRH', 'Forced', 2017, 9, 3.62),
#  ('TRMOS', 'Forced', 2017, 9, 0.12),
#  ('AUXC', 'Forced', 2017, 9, 0.0),
#  ('PUG', 'Forced', 2016, 8, 0.8),
#  ('EUCT', 'Consequential', 2016, 8, 0.45),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.38),
#  ('AURICON', 'Forced', 2016, 8, 0.08),
#  ('PMC', 'Forced', 2016, 8, 0.63),
#  ('PJRH', 'Forced', 2016, 8, 3.66),
#  ('AUXC', 'Forced', 2016, 8, 0.0),
#  ('ENRG', 'Scheduled (Planned)', 2016, 8, 1.66),
#  ('EUCT', 'Forced', 2016, 8, 1.03),
#  ('TRMOS', 'Forced', 2016, 8, 0.18),
#  ('GW', 'Forced', 2016, 8, 2.29),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.28),
#  ('TSLA_MGT', 'Consequential', 2017, 8, 0.4),
#  ('AUXC', 'Forced', 2017, 8, 0.0),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 8, 0.19),
#  ('TSLA_MGT', 'Forced', 2017, 8, 0.41),
#  ('COLLGAR', 'Forced', 2017, 8, 3.58),
#  ('TRMOS', 'Forced', 2017, 8, 0.02),
#  ('KORL', 'Forced', 2017, 8, 4.39),
#  ('PMC', 'Forced', 2017, 8, 0.29),
#  ('PJRH', 'Forced', 2017, 8, 0.62),
#  ('PJRH', 'Forced', 2016, 7, 0.21),
#  ('TSLA_MGT', 'Consequential', 2016, 7, 0.25),
#  ('TRMOS', 'Forced', 2016, 7, 0.36),
#  ('PMC', 'Forced', 2016, 7, 0.07),
#  ('PMC', 'Forced', 2016, 7, 3.1),
#  ('TRMOS', 'Forced', 2016, 7, 0.27),
#  ('AUXC', 'Forced', 2016, 7, 0.0),
#  ('PJRH', 'Forced', 2016, 7, 0.42),
#  ('COLLGAR', 'Forced', 2016, 7, 0.53),
#  ('AUXC', 'Forced', 2016, 7, 0.0),
#  ('ENRG', 'Scheduled (Planned)', 2017, 7, 2.76),
#  ('ENRG', 'Consequential', 2017, 7, 4.22),
#  ('TSLA_MGT', 'Consequential', 2017, 7, 0.27),
#  ('MCG', 'Forced', 2017, 7, 0.43),
#  ('PJRH', 'Forced', 2017, 7, 3.53),
#  ('COLLGAR', 'Forced', 2017, 7, 0.73),
#  ('AUXC', 'Forced', 2017, 7, 0.14),
#  ('COLLGAR', 'Forced', 2017, 7, 0.2),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 7, 0.28),
#  ('PJRH', 'Forced', 2016, 6, 0.27),
#  ('STHRNCRS', 'Forced', 2016, 6, 0.49),
#  ('ENRG', 'Forced', 2016, 6, 2.8),
#  ('COLLGAR', 'Forced', 2016, 6, 0.37),
#  ('KORL', 'Scheduled (Planned)', 2016, 6, 5.1),
#  ('MELK', 'Scheduled (Planned)', 2016, 6, 0.61),
#  ('STHRNCRS', 'Forced', 2016, 6, 0.31),
#  ('PUG', 'Forced', 2016, 6, 3.08),
#  ('PMC', 'Forced', 2016, 6, 0.01),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 6, 0.65),
#  ('PJRH', 'Forced', 2016, 6, 1.73),
#  ('ENRG', 'Scheduled (Planned)', 2017, 6, 4.52),
#  ('EUCT', 'Consequential', 2017, 6, 0.17),
#  ('KORL', 'Forced', 2017, 6, 0.28),
#  ('TSLA_MGT', 'Consequential', 2017, 6, 0.44),
#  ('DNHR', 'Consequential', 2017, 6, 0.3),
#  ('MELK', 'Scheduled (Planned)', 2017, 6, 2.38),
#  ('TSLA_MGT', 'Consequential', 2017, 6, 0.2),
#  ('PMC', 'Forced', 2017, 6, 0.62),
#  ('STHRNCRS', 'Forced', 2017, 6, 0.4),
#  ('COLLGAR', 'Forced', 2017, 6, 0.17),
#  ('ENRG', 'Forced', 2017, 6, 1.37),
#  ('KORL', 'Forced', 2017, 6, 4.56),
#  ('ENRG', 'Consequential', 2016, 5, 1.09),
#  ('PUG', 'Scheduled (Planned)', 2016, 5, 0.27),
#  ('KORL', 'Forced', 2016, 5, 0.5),
#  ('PMC', 'Forced', 2016, 5, 0.12),
#  ('KORL', 'Forced', 2016, 5, 0.31),
#  ('MUND', 'Scheduled (Planned)', 2016, 5, 6.38),
#  ('ENRG', 'Consequential', 2016, 5, 0.28),
#  ('PMC', 'Consequential', 2016, 5, 1.42),
#  ('ENRG', 'Scheduled (Planned)', 2016, 5, 3.44),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 5, 6.5),
#  ('ENRG', 'Forced', 2016, 5, 1.29),
#  ('ENRG', 'Consequential', 2016, 5, 9.54),
#  ('EUCT', 'Forced', 2016, 5, 2.99),
#  ('TSLA_MGT', 'Consequential', 2016, 5, 0.4),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.29),
#  ('ENRG', 'Scheduled (Planned)', 2017, 5, 0.93),
#  ('PMC', 'Consequential', 2017, 5, 5.46),
#  ('STHRNCRS', 'Forced', 2017, 5, 0.4),
#  ('TRMOS', 'Forced', 2017, 5, 0.07),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 5, 1.28),
#  ('PJRH', 'Forced', 2017, 5, 0.25),
#  ('ENRG', 'Scheduled (Planned)', 2017, 5, 2.13),
#  ('AUXC', 'Forced', 2017, 5, 0.06),
#  ('STHRNCRS', 'Forced', 2017, 5, 0.42),
#  ('WGUTD', 'Forced', 2017, 5, 0.12),
#  ('TSLA_MGT', 'Consequential', 2016, 4, 0.21),
#  ('ENRG', 'Consequential', 2016, 4, 6.96),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.13),
#  ('STHRNCRS', 'Forced', 2016, 4, 0.57),
#  ('EUCT', 'Consequential', 2016, 4, 0.23),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 4, 9.45),
#  ('PUG', 'Forced', 2016, 4, 0.29),
#  ('PMC', 'Scheduled (Planned)', 2016, 4, 9.61),
#  ('COLLGAR', 'Forced', 2016, 4, 0.08),
#  ('PMC', 'Consequential', 2016, 4, 0.38),
#  ('PUG', 'Forced', 2016, 4, 0.35),
#  ('STHRNCRS', 'Consequential', 2016, 4, 0.27),
#  ('COLLGAR', 'Forced', 2016, 4, 6.61),
#  ('PMC', 'Forced', 2016, 4, 0.17),
#  ('STHRNCRS', 'Forced', 2016, 4, 0.52),
#  ('TRMOS', 'Forced', 2016, 4, 1.73),
#  ('PUG', 'Forced', 2017, 4, 0.14),
#  ('TRMOS', 'Forced', 2017, 4, 0.39),
#  ('KORL', 'Scheduled (Planned)', 2017, 4, 0.11),
#  ('STHRNCRS', 'Forced', 2017, 4, 0.37),
#  ('KORL', 'Scheduled (Planned)', 2017, 4, 1.29),
#  ('PUG', 'Forced', 2017, 4, 5.02),
#  ('EUCT', 'Forced', 2017, 4, 0.15),
#  ('MUND', 'Scheduled (Planned)', 2017, 4, 2.74),
#  ('COLLGAR', 'Forced', 2017, 4, 0.01),
#  ('ENRG', 'Scheduled (Planned)', 2017, 4, 9.4),
#  ('STHRNCRS', 'Forced', 2017, 4, 0.62),
#  ('ENRG', 'Forced', 2017, 4, 4.58),
#  ('MCG', 'Forced', 2017, 4, 0.06),
#  ('PMC', 'Scheduled (Planned)', 2017, 4, 3.38),
#  ('GW', 'Forced', 2017, 4, 0.31),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06),
#  ('TSLA_MGT', 'Consequential', 2017, 4, 0.69),
#  ('TRMOS', 'Forced', 2016, 3, 0.32),
#  ('TSLA_MGT', 'Consequential', 2016, 3, 1.35),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.28),
#  ('PUG', 'Scheduled (Planned)', 2016, 3, 0.24),
#  ('STHRNCRS', 'Forced', 2016, 3, 0.38),
#  ('DNHR', 'Consequential', 2016, 3, 0.12),
#  ('TSLA_MGT', 'Consequential', 2016, 3, 0.96),
#  ('WGUTD', 'Consequential', 2016, 3, 0.65),
#  ('KORL', 'Forced', 2016, 3, 2.01),
#  ('PMC', 'Consequential', 2016, 3, 0.33),
#  ('COLLGAR', 'Forced', 2016, 3, 0.02),
#  ('KORL', 'Forced', 2016, 3, 0.22),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 3, 7.22),
#  ('TRMOS', 'Forced', 2016, 3, 0.31),
#  ('KORL', 'Scheduled (Planned)', 2016, 3, 18.03),
#  ('PUG', 'Scheduled (Planned)', 2016, 3, 0.16),
#  ('TRMOS', 'Forced', 2016, 3, 0.17),
#  ('WGUTD', 'Consequential', 2016, 3, 0.02),
#  ('TRMOS', 'Forced', 2017, 3, 0.26),
#  ('COLLGAR', 'Forced', 2017, 3, 0.68),
#  ('AUXC', 'Forced', 2017, 3, 0.99),
#  ('MUND', 'Forced', 2017, 3, 0.01),
#  ('ENRG', 'Scheduled (Planned)', 2017, 3, 8.2),
#  ('MUND', 'Forced', 2017, 3, 0.02),
#  ('COLLGAR', 'Forced', 2017, 3, 0.63),
#  ('EUCT', 'Consequential', 2017, 3, 0.12),
#  ('STHRNCRS', 'Forced', 2017, 3, 0.71),
#  ('TSLA_MGT', 'Consequential', 2017, 3, 1.18),
#  ('STHRNCRS', 'Forced', 2017, 3, 0.15),
#  ('WGUTD', 'Forced', 2017, 3, 8.98),
#  ('ENRG', 'Scheduled (Planned)', 2016, 2, 1.72),
#  ('PUG', 'Scheduled (Planned)', 2016, 2, 0.48),
#  ('MCG', 'Consequential', 2016, 2, 0.26),
#  ('STHRNCRS', 'Consequential', 2016, 2, 0.42),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 2, 5.18),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 2, 0.1),
#  ('STHRNCRS', 'Consequential', 2016, 2, 0.53),
#  ('ENRG', 'Scheduled (Planned)', 2016, 2, 2.48),
#  ('STHRNCRS', 'Forced', 2016, 2, 0.38),
#  ('DNHR', 'Consequential', 2016, 2, 0.73),
#  ('TRMOS', 'Forced', 2016, 2, 0.27),
#  ('DNHR', 'Consequential', 2016, 2, 0.18),
#  ('PUG', 'Forced', 2017, 2, 0.54),
#  ('DNHR', 'Consequential', 2017, 2, 0.26),
#  ('EUCT', 'Consequential', 2017, 2, 1.31),
#  ('MCG', 'Consequential', 2017, 2, 0.23),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.06),
#  ('PUG', 'Forced', 2017, 2, 0.18),
#  ('AUXC', 'Forced', 2017, 2, 0.0),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 2, 2.07),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 2, 0.28),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 5.34),
#  ('PMC', 'Forced', 2017, 2, 0.0),
#  ('ENRG', 'Scheduled (Planned)', 2017, 2, 1.02),
#  ('EUCT', 'Consequential', 2017, 2, 0.02),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 1, 1.56),
#  ('DNHR', 'Consequential', 2016, 1, 0.44),
#  ('MUND', 'Forced', 2016, 1, 0.73),
#  ('COLLGAR', 'Forced', 2016, 1, 0.06),
#  ('TRMOS', 'Forced', 2016, 1, 0.17),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 1, 1.42),
#  ('DNHR', 'Consequential', 2016, 1, 0.08),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42),
#  ('MUND', 'Scheduled (Planned)', 2016, 1, 8.92),
#  ('STHRNCRS', 'Consequential', 2016, 1, 0.04),
#  ('TSLA_MGT', 'Consequential', 2016, 1, 0.02),
#  ('WGUTD', 'Consequential', 2016, 1, 0.23),
#  ('DNHR', 'Consequential', 2016, 1, 0.35),
#  ('EUCT', 'Forced', 2016, 1, 9.81),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 1, 24.04),
#  ('DNHR', 'Forced', 2016, 1, 0.4),
#  ('EUCT', 'Forced', 2016, 1, 19.29),
#  ('PJRH', 'Forced', 2016, 1, 0.31),
#  ('TSLA_MGT', 'Consequential', 2016, 1, 0.02),
#  ('EUCT', 'Forced', 2016, 1, 15.02),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.21),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 1, 0.23),
#  ('MCG', 'Forced', 2016, 1, 0.79),
#  ('DNHR', 'Consequential', 2016, 1, 0.06),
#  ('MUND', 'Forced', 2016, 1, 0.06),
#  ('COLLGAR', 'Forced', 2017, 1, 0.0),
#  ('DNHR', 'Consequential', 2017, 1, 0.13),
#  ('KORL', 'Forced', 2017, 1, 0.17),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.02),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.0),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25),
#  ('PMC', 'Scheduled (Planned)', 2017, 1, 0.1),
#  ('DNHR', 'Consequential', 2017, 1, 0.33),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.65),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04),
#  ('DNHR', 'Consequential', 2017, 1, 0.33),
#  ('MCG', 'Forced', 2017, 1, 0.17),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.33),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.63),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.33),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.08),
#  ('TSLA_MGT', 'Consequential', 2017, 1, 0.31),
#  ('DNHR', 'Consequential', 2017, 1, 0.13),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.31),
#  ('DNHR', 'Consequential', 2017, 1, 0.17)]

# %% [markdown]
# We've identified participants who are having many outages, as well as participants who have been offline for the longest durations.
#
# Armed with this information, it's important we're able to classify our participants accordingly based on reliability metrics of uptime.
#
# We classify a participant based off the following criteria:
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day)</li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours</li>
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> 4. </h3>

# %% [markdown]
# <b> Using the above criteria for context, we will write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> that is based off their Average Outage Duration Time. Please note that this is for all valid (i.e. `Where status = approved`) outage types (Forced, Consequential, Scheduled, Opportunistic) for <u>all</u> participant codes from 2016 to 2017. Order the results using `Average Duration Time In Days` in descending order.

# %%
# %%sql
#
# WITH Outage AS (
# Select
# Participant_Code,
# Outage_Reason,
# Year,
# COUNT(*) AS Total_Number_Outage_Events,
# ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Year, Month, Participant_Code
# ORDER BY Average_Outage_Duration_In_Days DESC
# )
#
# SELECT *,
# CASE
#     WHEN Average_Outage_Duration_In_Days > 1 THEN 'High Risk'
#     WHEN Average_Outage_Duration_In_Days BETWEEN 0.5 AND 1 THEN 'Medium Risk'
#     WHEN Average_Outage_Duration_In_Days < 0.5 THEN 'Low Risk'
# END AS Risk_Classification
# FROM Outage
# ;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('COLLGAR', 'Scheduled (Planned)', 2016, 1, 24.04, 'High Risk'),
#  ('EUCT', 'Forced', 2016, 1, 19.29, 'High Risk'),
#  ('KORL', 'Scheduled (Planned)', 2016, 3, 18.03, 'High Risk'),
#  ('EUCT', 'Forced', 2016, 1, 15.02, 'High Risk'),
#  ('MELK', 'Forced', 2017, 28, 11.67, 'High Risk'),
#  ('EUCT', 'Forced', 2016, 1, 9.81, 'High Risk'),
#  ('PMC', 'Scheduled (Planned)', 2016, 4, 9.61, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 5, 9.54, 'High Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 4, 9.45, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 4, 9.4, 'High Risk'),
#  ('WGUTD', 'Forced', 2017, 3, 8.98, 'High Risk'),
#  ('MUND', 'Scheduled (Planned)', 2016, 1, 8.92, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 3, 8.2, 'High Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 3, 7.22, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 4, 6.96, 'High Risk'),
#  ('COLLGAR', 'Forced', 2016, 4, 6.61, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 5, 6.5, 'High Risk'),
#  ('MUND', 'Scheduled (Planned)', 2016, 5, 6.38, 'High Risk'),
#  ('PMC', 'Consequential', 2017, 5, 5.46, 'High Risk'),
#  ('MELK', 'Forced', 2016, 11, 5.45, 'High Risk'),
#  ('COLLGAR', 'Forced', 2017, 14, 5.44, 'High Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 5.34, 'High Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 2, 5.18, 'High Risk'),
#  ('KORL', 'Scheduled (Planned)', 2016, 6, 5.1, 'High Risk'),
#  ('PUG', 'Forced', 2017, 4, 5.02, 'High Risk'),
#  ('GW', 'Consequential', 2017, 16, 4.86, 'High Risk'),
#  ('ENRG', 'Forced', 2017, 4, 4.58, 'High Risk'),
#  ('KORL', 'Forced', 2017, 6, 4.56, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 6, 4.52, 'High Risk'),
#  ('KORL', 'Forced', 2017, 8, 4.39, 'High Risk'),
#  ('ENRG', 'Consequential', 2017, 7, 4.22, 'High Risk'),
#  ('GW', 'Forced', 2017, 15, 4.21, 'High Risk'),
#  ('KORL', 'Forced', 2017, 10, 3.94, 'High Risk'),
#  ('MELK', 'Forced', 2016, 10, 3.87, 'High Risk'),
#  ('MELK', 'Forced', 2017, 12, 3.85, 'High Risk'),
#  ('MELK', 'Forced', 2017, 15, 3.74, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 8, 3.66, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 9, 3.62, 'High Risk'),
#  ('COLLGAR', 'Forced', 2017, 8, 3.58, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 7, 3.53, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 5, 3.44, 'High Risk'),
#  ('MELK', 'Forced', 2016, 24, 3.42, 'High Risk'),
#  ('PMC', 'Scheduled (Planned)', 2017, 4, 3.38, 'High Risk'),
#  ('MELK', 'Forced', 2017, 29, 3.36, 'High Risk'),
#  ('MELK', 'Forced', 2017, 15, 3.31, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 15, 3.25, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 13, 3.23, 'High Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 16, 3.1, 'High Risk'),
#  ('PMC', 'Forced', 2016, 7, 3.1, 'High Risk'),
#  ('PUG', 'Forced', 2016, 6, 3.08, 'High Risk'),
#  ('EUCT', 'Forced', 2016, 5, 2.99, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 19, 2.89, 'High Risk'),
#  ('GW', 'Forced', 2017, 21, 2.85, 'High Risk'),
#  ('ENRG', 'Forced', 2016, 6, 2.8, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 7, 2.76, 'High Risk'),
#  ('MUND', 'Scheduled (Planned)', 2017, 4, 2.74, 'High Risk'),
#  ('KORL', 'Forced', 2017, 12, 2.69, 'High Risk'),
#  ('MELK', 'Forced', 2017, 17, 2.63, 'High Risk'),
#  ('MELK', 'Forced', 2016, 38, 2.6, 'High Risk'),
#  ('GW', 'Consequential', 2016, 35, 2.52, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 2, 2.48, 'High Risk'),
#  ('MELK', 'Scheduled (Planned)', 2017, 6, 2.38, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 13, 2.36, 'High Risk'),
#  ('GW', 'Forced', 2016, 8, 2.29, 'High Risk'),
#  ('MELK', 'Forced', 2017, 16, 2.14, 'High Risk'),
#  ('COLLGAR', 'Consequential', 2016, 14, 2.13, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 5, 2.13, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 15, 2.09, 'High Risk'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 2, 2.07, 'High Risk'),
#  ('KORL', 'Forced', 2016, 3, 2.01, 'High Risk'),
#  ('MELK', 'Forced', 2017, 41, 1.94, 'High Risk'),
#  ('MELK', 'Forced', 2016, 34, 1.93, 'High Risk'),
#  ('MELK', 'Forced', 2017, 28, 1.93, 'High Risk'),
#  ('MELK', 'Forced', 2017, 29, 1.76, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 6, 1.73, 'High Risk'),
#  ('TRMOS', 'Forced', 2016, 4, 1.73, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 2, 1.72, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 22, 1.72, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 10, 1.72, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 8, 1.66, 'High Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 10, 1.61, 'High Risk'),
#  ('MELK', 'Forced', 2017, 27, 1.6, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 20, 1.59, 'High Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 1, 1.56, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 17, 1.52, 'High Risk'),
#  ('GW', 'Forced', 2017, 15, 1.51, 'High Risk'),
#  ('MELK', 'Forced', 2016, 29, 1.43, 'High Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 1, 1.42, 'High Risk'),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42, 'High Risk'),
#  ('PMC', 'Consequential', 2016, 5, 1.42, 'High Risk'),
#  ('ENRG', 'Forced', 2017, 6, 1.37, 'High Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 3, 1.35, 'High Risk'),
#  ('EUCT', 'Consequential', 2017, 2, 1.31, 'High Risk'),
#  ('ENRG', 'Forced', 2016, 5, 1.29, 'High Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 4, 1.29, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 9, 1.28, 'High Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 5, 1.28, 'High Risk'),
#  ('GW', 'Forced', 2017, 11, 1.21, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 15, 1.19, 'High Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 3, 1.18, 'High Risk'),
#  ('GW', 'Forced', 2016, 30, 1.15, 'High Risk'),
#  ('KORL', 'Forced', 2016, 9, 1.13, 'High Risk'),
#  ('MELK', 'Forced', 2016, 16, 1.13, 'High Risk'),
#  ('GW', 'Forced', 2017, 23, 1.1, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 5, 1.09, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 14, 1.07, 'High Risk'),
#  ('EUCT', 'Forced', 2016, 8, 1.03, 'High Risk'),
#  ('MELK', 'Forced', 2016, 21, 1.03, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 30, 1.02, 'High Risk'),
#  ('GW', 'Forced', 2016, 11, 1.02, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 2, 1.02, 'High Risk'),
#  ('MELK', 'Forced', 2016, 26, 0.99, 'Medium Risk'),
#  ('AUXC', 'Forced', 2017, 3, 0.99, 'Medium Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 26, 0.98, 'Medium Risk'),
#  ('AUXC', 'Forced', 2016, 11, 0.97, 'Medium Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 3, 0.96, 'Medium Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 5, 0.93, 'Medium Risk'),
#  ('MELK', 'Forced', 2016, 42, 0.92, 'Medium Risk'),
#  ('PUG', 'Forced', 2017, 20, 0.91, 'Medium Risk'),
#  ('GW', 'Forced', 2016, 22, 0.85, 'Medium Risk'),
#  ('PUG', 'Forced', 2016, 8, 0.8, 'Medium Risk'),
#  ('MCG', 'Forced', 2016, 1, 0.79, 'Medium Risk'),
#  ('KORL', 'Forced', 2017, 19, 0.77, 'Medium Risk'),
#  ('GW', 'Forced', 2016, 24, 0.74, 'Medium Risk'),
#  ('MUND', 'Forced', 2016, 1, 0.73, 'Medium Risk'),
#  ('DNHR', 'Consequential', 2016, 2, 0.73, 'Medium Risk'),
#  ('COLLGAR', 'Forced', 2017, 7, 0.73, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2017, 3, 0.71, 'Medium Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 4, 0.69, 'Medium Risk'),
#  ('COLLGAR', 'Forced', 2017, 3, 0.68, 'Medium Risk'),
#  ('WGUTD', 'Consequential', 2016, 3, 0.65, 'Medium Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 6, 0.65, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.65, 'Medium Risk'),
#  ('PMC', 'Forced', 2016, 8, 0.63, 'Medium Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.63, 'Medium Risk'),
#  ('COLLGAR', 'Forced', 2017, 3, 0.63, 'Medium Risk'),
#  ('TSLA_MGT', 'Forced', 2016, 9, 0.62, 'Medium Risk'),
#  ('PMC', 'Forced', 2017, 6, 0.62, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2017, 4, 0.62, 'Medium Risk'),
#  ('PJRH', 'Forced', 2017, 8, 0.62, 'Medium Risk'),
#  ('MELK', 'Scheduled (Planned)', 2016, 6, 0.61, 'Medium Risk'),
#  ('GW', 'Forced', 2016, 110, 0.61, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2016, 4, 0.57, 'Medium Risk'),
#  ('PUG', 'Forced', 2017, 2, 0.54, 'Medium Risk'),
#  ('STHRNCRS', 'Consequential', 2016, 2, 0.53, 'Medium Risk'),
#  ('COLLGAR', 'Forced', 2016, 7, 0.53, 'Medium Risk'),
#  ('AURICON', 'Consequential', 2017, 14, 0.53, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2016, 4, 0.52, 'Medium Risk'),
#  ('PUG', 'Forced', 2017, 19, 0.52, 'Medium Risk'),
#  ('GW', 'Consequential', 2017, 18, 0.52, 'Medium Risk'),
#  ('KORL', 'Forced', 2016, 5, 0.5, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2016, 6, 0.49, 'Low Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.49, 'Low Risk'),
#  ('PUG', 'Scheduled (Planned)', 2016, 2, 0.48, 'Low Risk'),
#  ('EUCT', 'Consequential', 2016, 8, 0.45, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 1, 0.44, 'Low Risk'),
#  ('GW', 'Forced', 2016, 52, 0.44, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 18, 0.44, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 6, 0.44, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 18, 0.44, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 10, 0.43, 'Low Risk'),
#  ('MCG', 'Forced', 2017, 7, 0.43, 'Low Risk'),
#  ('GW', 'Forced', 2017, 14, 0.43, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2016, 2, 0.42, 'Low Risk'),
#  ('PJRH', 'Forced', 2016, 7, 0.42, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 5, 0.42, 'Low Risk'),
#  ('KORL', 'Forced', 2016, 9, 0.41, 'Low Risk'),
#  ('TSLA_MGT', 'Forced', 2017, 8, 0.41, 'Low Risk'),
#  ('GW', 'Forced', 2017, 67, 0.41, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 10, 0.4, 'Low Risk'),
#  ('GW', 'Forced', 2016, 55, 0.4, 'Low Risk'),
#  ('DNHR', 'Forced', 2016, 1, 0.4, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 5, 0.4, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 8, 0.4, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 5, 0.4, 'Low Risk'),
#  ('GW', 'Forced', 2017, 16, 0.4, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 6, 0.4, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.39, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 4, 0.39, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.38, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2016, 3, 0.38, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2016, 2, 0.38, 'Low Risk'),
#  ('PMC', 'Consequential', 2016, 4, 0.38, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2016, 6, 0.37, 'Low Risk'),
#  ('PJRH', 'Forced', 2016, 18, 0.37, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 4, 0.37, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 7, 0.36, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 24, 0.36, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 1, 0.35, 'Low Risk'),
#  ('PUG', 'Forced', 2016, 4, 0.35, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 9, 0.35, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 29, 0.35, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 11, 0.34, 'Low Risk'),
#  ('KORL', 'Consequential', 2017, 11, 0.34, 'Low Risk'),
#  ('PMC', 'Consequential', 2016, 3, 0.33, 'Low Risk'),
#  ('PJRH', 'Forced', 2017, 11, 0.33, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 1, 0.33, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 1, 0.33, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.33, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.33, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 3, 0.32, 'Low Risk'),
#  ('KORL', 'Forced', 2016, 5, 0.31, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2016, 6, 0.31, 'Low Risk'),
#  ('PJRH', 'Forced', 2016, 1, 0.31, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 3, 0.31, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 1, 0.31, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.31, 'Low Risk'),
#  ('GW', 'Forced', 2017, 4, 0.31, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 32, 0.3, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 6, 0.3, 'Low Risk'),
#  ('PMC', 'Scheduled (Planned)', 2016, 39, 0.29, 'Low Risk'),
#  ('PUG', 'Forced', 2016, 4, 0.29, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.29, 'Low Risk'),
#  ('PMC', 'Forced', 2017, 8, 0.29, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 15, 0.29, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 31, 0.29, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.28, 'Low Risk'),
#  ('ENRG', 'Consequential', 2016, 5, 0.28, 'Low Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.28, 'Low Risk'),
#  ('KORL', 'Forced', 2017, 6, 0.28, 'Low Risk'),
#  ('MUND', 'Forced', 2017, 10, 0.28, 'Low Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 2, 0.28, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 7, 0.28, 'Low Risk'),
#  ('PJRH', 'Forced', 2016, 6, 0.27, 'Low Risk'),
#  ('PUG', 'Scheduled (Planned)', 2016, 5, 0.27, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 7, 0.27, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 2, 0.27, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2016, 4, 0.27, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 7, 0.27, 'Low Risk'),
#  ('MCG', 'Consequential', 2016, 2, 0.26, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 3, 0.26, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 2, 0.26, 'Low Risk'),
#  ('AUXC', 'Consequential', 2016, 27, 0.25, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 7, 0.25, 'Low Risk'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 29, 0.25, 'Low Risk'),
#  ('PJRH', 'Forced', 2017, 5, 0.25, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 52, 0.25, 'Low Risk'),
#  ('PUG', 'Scheduled (Planned)', 2016, 3, 0.24, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 86, 0.24, 'Low Risk'),
#  ('EUCT', 'Consequential', 2016, 4, 0.23, 'Low Risk'),
#  ('WGUTD', 'Consequential', 2016, 1, 0.23, 'Low Risk'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 1, 0.23, 'Low Risk'),
#  ('MCG', 'Consequential', 2017, 2, 0.23, 'Low Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 0.22, 'Low Risk'),
#  ('KORL', 'Forced', 2016, 3, 0.22, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 24, 0.22, 'Low Risk'),
#  ('PJRH', 'Forced', 2016, 17, 0.21, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 4, 0.21, 'Low Risk'),
#  ('PJRH', 'Forced', 2016, 7, 0.21, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 12, 0.21, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.21, 'Low Risk'),
#  ('PMC', 'Consequential', 2017, 10, 0.21, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 13, 0.2, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 6, 0.2, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 7, 0.2, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 32, 0.19, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 63, 0.19, 'Low Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 8, 0.19, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 8, 0.18, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 2, 0.18, 'Low Risk'),
#  ('PUG', 'Forced', 2017, 2, 0.18, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 1, 0.17, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 3, 0.17, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 4, 0.17, 'Low Risk'),
#  ('KORL', 'Forced', 2017, 1, 0.17, 'Low Risk'),
#  ('EUCT', 'Consequential', 2017, 6, 0.17, 'Low Risk'),
#  ('MCG', 'Forced', 2017, 1, 0.17, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 6, 0.17, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 1, 0.17, 'Low Risk'),
#  ('PUG', 'Scheduled (Planned)', 2016, 3, 0.16, 'Low Risk'),
#  ('EUCT', 'Forced', 2017, 4, 0.15, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 30, 0.15, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 3, 0.15, 'Low Risk'),
#  ('GW', 'Forced', 2016, 10, 0.14, 'Low Risk'),
#  ('PUG', 'Forced', 2017, 4, 0.14, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 125, 0.14, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 7, 0.14, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 95, 0.14, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.13, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 33, 0.13, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 1, 0.13, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 1, 0.13, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 5, 0.12, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 3, 0.12, 'Low Risk'),
#  ('MUND', 'Forced', 2016, 11, 0.12, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 45, 0.12, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 9, 0.12, 'Low Risk'),
#  ('WGUTD', 'Forced', 2017, 5, 0.12, 'Low Risk'),
#  ('EUCT', 'Consequential', 2017, 3, 0.12, 'Low Risk'),
#  ('GW', 'Forced', 2016, 19, 0.11, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 4, 0.11, 'Low Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 2, 0.1, 'Low Risk'),
#  ('PMC', 'Scheduled (Planned)', 2017, 1, 0.1, 'Low Risk'),
#  ('PUG', 'Forced', 2017, 10, 0.1, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 8, 0.08, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 1, 0.08, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2016, 4, 0.08, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 20, 0.08, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 14, 0.08, 'Low Risk'),
#  ('PUG', 'Forced', 2017, 21, 0.08, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.08, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 29, 0.07, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 7, 0.07, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 20, 0.07, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 5, 0.07, 'Low Risk'),
#  ('AURICON', 'Forced', 2017, 28, 0.07, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 32, 0.07, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2016, 1, 0.06, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 1, 0.06, 'Low Risk'),
#  ('MUND', 'Forced', 2016, 1, 0.06, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.06, 'Low Risk'),
#  ('PMC', 'Forced', 2017, 15, 0.06, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 13, 0.06, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 5, 0.06, 'Low Risk'),
#  ('MCG', 'Forced', 2017, 4, 0.06, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 16, 0.06, 'Low Risk'),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06, 'Low Risk'),
#  ('PMC', 'Consequential', 2017, 10, 0.05, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 20, 0.05, 'Low Risk'),
#  ('AURICON', 'Forced', 2016, 42, 0.04, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 15, 0.04, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2016, 1, 0.04, 'Low Risk'),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.04, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 14, 0.03, 'Low Risk'),
#  ('GW', 'Forced', 2017, 50, 0.03, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 1, 0.02, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2016, 3, 0.02, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 1, 0.02, 'Low Risk'),
#  ('WGUTD', 'Consequential', 2016, 3, 0.02, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.02, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 8, 0.02, 'Low Risk'),
#  ('PUG', 'Forced', 2017, 33, 0.02, 'Low Risk'),
#  ('MUND', 'Forced', 2017, 3, 0.02, 'Low Risk'),
#  ('PUG', 'Forced', 2017, 11, 0.02, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 13, 0.02, 'Low Risk'),
#  ('EUCT', 'Consequential', 2017, 2, 0.02, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 6, 0.01, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 4, 0.01, 'Low Risk'),
#  ('PUG', 'Forced', 2017, 13, 0.01, 'Low Risk'),
#  ('MUND', 'Forced', 2017, 3, 0.01, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 38, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 12, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 21, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 13, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 8, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 7, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 17, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 7, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 19, 0.0, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 1, 0.0, 'Low Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 19, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 8, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 2, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 9, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 11, 0.0, 'Low Risk'),
#  ('PMC', 'Forced', 2017, 2, 0.0, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 31, 0.0, 'Low Risk')]

# %% [markdown]
# Now that we've classified our participants as either `High Risk`, `Medium Risk` or `Low Risk`, we want to dig a little deeper.
#
# Does it make sense that `Consequential`, `Opportunistic` or `Planned` aren't considered regarding the Risk Category?
#
# Perhaps we should refine our category accordingly by ensuring we focus our Risk Category on labelling only `Forced` Outages as being a Risk. After all, Forced Outages are the unplanned outages that risk the security of the electricity grid.
#
# Let's add two additional criteria to our classification considering `Total Number of Outage Events` and `Outage Type`.
#
# We've summarised these below:
#
# <b>
# <li> High Risk - On average, the participant is unavailable for > 24 Hours (1 Day) OR the Total Number of Outage Events > 20 </li>
# <li> Medium Risk - On average, the participant is unavailable between 12 and 24 Hours OR the Total Number of Outage Events is Between 10 and 20 </li>
# <li> Low Risk - On average, the participant is unavailable for less than 12 Hours OR the Total Number of Outage Events < 10 </li>
# <li> If Outage Type is not forced, then N/A
# </b>

# %% [markdown]
# <h3 style="color:#D4AF37"> 5. </h3>

# %% [markdown]
# <b> Using the above criteria for context, we will write a SQL Statement that <u> classifies each participant code as either `High Risk`, `Medium Risk` or `Low Risk` in a column called `Risk_Classification`</u> using the new classification criteria. Order the results using `Average Duration Time In Days` in descending order.

# %%
# %%sql
#
# WITH Outage AS (
# Select
# Participant_Code,
# Outage_Reason,
# Year,
# COUNT(*) AS Total_Number_Outage_Events,
# ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Average_Outage_Duration_In_Days
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Year, Month, Participant_Code
# ORDER BY Total_Number_Outage_Events DESC
# )
#
# SELECT *,
# CASE
#     WHEN Average_Outage_Duration_In_Days > 1 AND Outage_Reason= 'Forced' OR Total_Number_Outage_Events> 20 AND Outage_Reason = 'Forced' THEN 'High Risk'
#     WHEN Average_Outage_Duration_In_Days BETWEEN 0.5 AND 1 AND Outage_Reason = 'Forced'OR Total_Number_Outage_Events BETWEEN 10 AND 20 AND Outage_Reason = 'Forced'THEN 'Medium Risk'
#     WHEN Average_Outage_Duration_In_Days < 0.5 AND Outage_Reason = 'Forced'OR Total_Number_Outage_Events <10 AND Outage_Reason = 'Forced'THEN 'Low Risk'
#     ELSE 'N/A'
# END AS Risk_Classification
# FROM Outage
# ;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'Forced', 2017, 125, 0.14, 'High Risk'),
#  ('GW', 'Forced', 2016, 110, 0.61, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 95, 0.14, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 86, 0.24, 'High Risk'),
#  ('GW', 'Forced', 2017, 67, 0.41, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 63, 0.19, 'High Risk'),
#  ('GW', 'Forced', 2016, 55, 0.4, 'High Risk'),
#  ('GW', 'Forced', 2016, 52, 0.44, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 52, 0.25, 'High Risk'),
#  ('GW', 'Forced', 2017, 50, 0.03, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 45, 0.12, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 42, 0.04, 'High Risk'),
#  ('MELK', 'Forced', 2016, 42, 0.92, 'High Risk'),
#  ('MELK', 'Forced', 2017, 41, 1.94, 'High Risk'),
#  ('PMC', 'Scheduled (Planned)', 2016, 39, 0.29, 'N/A'),
#  ('MELK', 'Forced', 2016, 38, 2.6, 'High Risk'),
#  ('AUXC', 'Forced', 2016, 38, 0.0, 'High Risk'),
#  ('GW', 'Consequential', 2016, 35, 2.52, 'N/A'),
#  ('MELK', 'Forced', 2016, 34, 1.93, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 33, 0.13, 'High Risk'),
#  ('PUG', 'Forced', 2017, 33, 0.02, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 32, 0.19, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 32, 0.3, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 32, 0.07, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 31, 0.29, 'High Risk'),
#  ('AUXC', 'Forced', 2017, 31, 0.0, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 30, 1.02, 'N/A'),
#  ('GW', 'Forced', 2016, 30, 1.15, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 30, 0.15, 'High Risk'),
#  ('AUXC', 'Forced', 2016, 29, 0.07, 'High Risk'),
#  ('MELK', 'Forced', 2016, 29, 1.43, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 29, 0.35, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 29, 0.25, 'High Risk'),
#  ('MELK', 'Forced', 2017, 29, 1.76, 'High Risk'),
#  ('MELK', 'Forced', 2017, 29, 3.36, 'High Risk'),
#  ('MELK', 'Forced', 2017, 28, 1.93, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 28, 0.07, 'High Risk'),
#  ('MELK', 'Forced', 2017, 28, 11.67, 'High Risk'),
#  ('AUXC', 'Consequential', 2016, 27, 0.25, 'N/A'),
#  ('MELK', 'Forced', 2017, 27, 1.6, 'High Risk'),
#  ('MELK', 'Forced', 2016, 26, 0.99, 'High Risk'),
#  ('GW', 'Opportunistic Maintenance (Planned)', 2016, 26, 0.98, 'N/A'),
#  ('MELK', 'Forced', 2016, 24, 3.42, 'High Risk'),
#  ('GW', 'Forced', 2016, 24, 0.74, 'High Risk'),
#  ('AURICON', 'Forced', 2017, 24, 0.22, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 24, 0.36, 'N/A'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 23, 0.39, 'N/A'),
#  ('GW', 'Forced', 2017, 23, 1.1, 'High Risk'),
#  ('AURICON', 'Forced', 2016, 22, 1.72, 'High Risk'),
#  ('GW', 'Forced', 2016, 22, 0.85, 'High Risk'),
#  ('AUXC', 'Forced', 2016, 21, 0.0, 'High Risk'),
#  ('MELK', 'Forced', 2016, 21, 1.03, 'High Risk'),
#  ('GW', 'Forced', 2017, 21, 2.85, 'High Risk'),
#  ('PUG', 'Forced', 2017, 21, 0.08, 'High Risk'),
#  ('TRMOS', 'Forced', 2016, 20, 0.07, 'Medium Risk'),
#  ('AURICON', 'Forced', 2017, 20, 0.08, 'Medium Risk'),
#  ('TRMOS', 'Forced', 2017, 20, 1.59, 'High Risk'),
#  ('PUG', 'Forced', 2017, 20, 0.91, 'Medium Risk'),
#  ('TRMOS', 'Forced', 2017, 20, 0.05, 'Medium Risk'),
#  ('GW', 'Forced', 2016, 19, 0.11, 'Medium Risk'),
#  ('PJRH', 'Forced', 2016, 19, 2.89, 'High Risk'),
#  ('AUXC', 'Forced', 2016, 19, 0.0, 'Medium Risk'),
#  ('AUXC', 'Forced', 2017, 19, 0.0, 'Medium Risk'),
#  ('PUG', 'Forced', 2017, 19, 0.52, 'Medium Risk'),
#  ('KORL', 'Forced', 2017, 19, 0.77, 'Medium Risk'),
#  ('PJRH', 'Forced', 2016, 18, 0.37, 'Medium Risk'),
#  ('AURICON', 'Forced', 2016, 18, 0.44, 'Medium Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 18, 0.44, 'N/A'),
#  ('GW', 'Consequential', 2017, 18, 0.52, 'N/A'),
#  ('PJRH', 'Forced', 2016, 17, 0.21, 'Medium Risk'),
#  ('AUXC', 'Forced', 2016, 17, 0.0, 'Medium Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 17, 1.52, 'N/A'),
#  ('MELK', 'Forced', 2017, 17, 2.63, 'High Risk'),
#  ('MELK', 'Opportunistic Maintenance (Planned)', 2016, 16, 3.1, 'N/A'),
#  ('MELK', 'Forced', 2016, 16, 1.13, 'High Risk'),
#  ('MELK', 'Forced', 2017, 16, 2.14, 'High Risk'),
#  ('GW', 'Consequential', 2017, 16, 4.86, 'N/A'),
#  ('GW', 'Forced', 2017, 16, 0.4, 'Medium Risk'),
#  ('TRMOS', 'Forced', 2017, 16, 0.06, 'Medium Risk'),
#  ('PMC', 'Forced', 2016, 15, 0.04, 'Medium Risk'),
#  ('AURICON', 'Forced', 2016, 15, 1.19, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 15, 3.25, 'High Risk'),
#  ('GW', 'Forced', 2017, 15, 1.51, 'High Risk'),
#  ('MELK', 'Forced', 2017, 15, 3.31, 'High Risk'),
#  ('MELK', 'Forced', 2017, 15, 3.74, 'High Risk'),
#  ('GW', 'Forced', 2017, 15, 4.21, 'High Risk'),
#  ('PMC', 'Forced', 2017, 15, 0.06, 'Medium Risk'),
#  ('TRMOS', 'Forced', 2017, 15, 2.09, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 15, 0.29, 'N/A'),
#  ('COLLGAR', 'Consequential', 2016, 14, 2.13, 'N/A'),
#  ('AUXC', 'Forced', 2017, 14, 0.03, 'Medium Risk'),
#  ('AURICON', 'Consequential', 2017, 14, 0.53, 'N/A'),
#  ('PJRH', 'Forced', 2017, 14, 1.07, 'High Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 14, 0.08, 'N/A'),
#  ('GW', 'Forced', 2017, 14, 0.43, 'Medium Risk'),
#  ('COLLGAR', 'Forced', 2017, 14, 5.44, 'High Risk'),
#  ('TRMOS', 'Forced', 2016, 13, 0.2, 'Medium Risk'),
#  ('AUXC', 'Forced', 2016, 13, 0.0, 'Medium Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 13, 3.23, 'N/A'),
#  ('PUG', 'Forced', 2017, 13, 0.01, 'Medium Risk'),
#  ('TRMOS', 'Forced', 2017, 13, 0.06, 'Medium Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 13, 2.36, 'N/A'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2017, 13, 0.04, 'N/A'),
#  ('AUXC', 'Forced', 2017, 13, 0.02, 'Medium Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 12, 0.22, 'N/A'),
#  ('AUXC', 'Forced', 2016, 12, 0.0, 'Medium Risk'),
#  ('AURICON', 'Forced', 2016, 12, 0.21, 'Medium Risk'),
#  ('MELK', 'Forced', 2017, 12, 3.85, 'High Risk'),
#  ('KORL', 'Forced', 2017, 12, 2.69, 'High Risk'),
#  ('MELK', 'Forced', 2016, 11, 5.45, 'High Risk'),
#  ('AUXC', 'Forced', 2016, 11, 0.97, 'Medium Risk'),
#  ('MUND', 'Forced', 2016, 11, 0.12, 'Medium Risk'),
#  ('AURICON', 'Forced', 2016, 11, 0.34, 'Medium Risk'),
#  ('GW', 'Forced', 2016, 11, 1.02, 'High Risk'),
#  ('PJRH', 'Forced', 2017, 11, 0.33, 'Medium Risk'),
#  ('KORL', 'Consequential', 2017, 11, 0.34, 'N/A'),
#  ('AUXC', 'Forced', 2017, 11, 0.0, 'Medium Risk'),
#  ('PUG', 'Forced', 2017, 11, 0.02, 'Medium Risk'),
#  ('GW', 'Forced', 2017, 11, 1.21, 'High Risk'),
#  ('GW', 'Forced', 2016, 10, 0.14, 'Medium Risk'),
#  ('AURICON', 'Forced', 2016, 10, 0.43, 'Medium Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 10, 0.4, 'N/A'),
#  ('MELK', 'Forced', 2016, 10, 3.87, 'High Risk'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 10, 1.61, 'N/A'),
#  ('PMC', 'Consequential', 2017, 10, 0.05, 'N/A'),
#  ('KORL', 'Forced', 2017, 10, 3.94, 'High Risk'),
#  ('MUND', 'Forced', 2017, 10, 0.28, 'Medium Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 10, 1.72, 'N/A'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2017, 10, 0.49, 'N/A'),
#  ('PMC', 'Consequential', 2017, 10, 0.21, 'N/A'),
#  ('PUG', 'Forced', 2017, 10, 0.1, 'Medium Risk'),
#  ('ENRG', 'Consequential', 2016, 9, 1.28, 'N/A'),
#  ('KORL', 'Forced', 2016, 9, 1.13, 'High Risk'),
#  ('KORL', 'Forced', 2016, 9, 0.41, 'Low Risk'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 9, 0.35, 'N/A'),
#  ('TSLA_MGT', 'Forced', 2016, 9, 0.62, 'Medium Risk'),
#  ('PJRH', 'Forced', 2017, 9, 3.62, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 9, 0.12, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 9, 0.0, 'Low Risk'),
#  ('PUG', 'Forced', 2016, 8, 0.8, 'Medium Risk'),
#  ('EUCT', 'Consequential', 2016, 8, 0.45, 'N/A'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.38, 'N/A'),
#  ('AURICON', 'Forced', 2016, 8, 0.08, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 8, 0.63, 'Medium Risk'),
#  ('PJRH', 'Forced', 2016, 8, 3.66, 'High Risk'),
#  ('AUXC', 'Forced', 2016, 8, 0.0, 'Low Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 8, 1.66, 'N/A'),
#  ('EUCT', 'Forced', 2016, 8, 1.03, 'High Risk'),
#  ('TRMOS', 'Forced', 2016, 8, 0.18, 'Low Risk'),
#  ('GW', 'Forced', 2016, 8, 2.29, 'High Risk'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2016, 8, 0.28, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2017, 8, 0.4, 'N/A'),
#  ('AUXC', 'Forced', 2017, 8, 0.0, 'Low Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2017, 8, 0.19, 'N/A'),
#  ('TSLA_MGT', 'Forced', 2017, 8, 0.41, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 8, 3.58, 'High Risk'),
#  ('TRMOS', 'Forced', 2017, 8, 0.02, 'Low Risk'),
#  ('KORL', 'Forced', 2017, 8, 4.39, 'High Risk'),
#  ('PMC', 'Forced', 2017, 8, 0.29, 'Low Risk'),
#  ('PJRH', 'Forced', 2017, 8, 0.62, 'Medium Risk'),
#  ('PJRH', 'Forced', 2016, 7, 0.21, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 7, 0.25, 'N/A'),
#  ('TRMOS', 'Forced', 2016, 7, 0.36, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 7, 0.07, 'Low Risk'),
#  ('PMC', 'Forced', 2016, 7, 3.1, 'High Risk'),
#  ('TRMOS', 'Forced', 2016, 7, 0.27, 'Low Risk'),
#  ('AUXC', 'Forced', 2016, 7, 0.0, 'Low Risk'),
#  ('PJRH', 'Forced', 2016, 7, 0.42, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2016, 7, 0.53, 'Medium Risk'),
#  ('AUXC', 'Forced', 2016, 7, 0.0, 'Low Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 7, 2.76, 'N/A'),
#  ('ENRG', 'Consequential', 2017, 7, 4.22, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2017, 7, 0.27, 'N/A'),
#  ('MCG', 'Forced', 2017, 7, 0.43, 'Low Risk'),
#  ('PJRH', 'Forced', 2017, 7, 3.53, 'High Risk'),
#  ('COLLGAR', 'Forced', 2017, 7, 0.73, 'Medium Risk'),
#  ('AUXC', 'Forced', 2017, 7, 0.14, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 7, 0.2, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 7, 0.28, 'N/A'),
#  ('PJRH', 'Forced', 2016, 6, 0.27, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2016, 6, 0.49, 'Low Risk'),
#  ('ENRG', 'Forced', 2016, 6, 2.8, 'High Risk'),
#  ('COLLGAR', 'Forced', 2016, 6, 0.37, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2016, 6, 5.1, 'N/A'),
#  ('MELK', 'Scheduled (Planned)', 2016, 6, 0.61, 'N/A'),
#  ('STHRNCRS', 'Forced', 2016, 6, 0.31, 'Low Risk'),
#  ('PUG', 'Forced', 2016, 6, 3.08, 'High Risk'),
#  ('PMC', 'Forced', 2016, 6, 0.01, 'Low Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 6, 0.65, 'N/A'),
#  ('PJRH', 'Forced', 2016, 6, 1.73, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 6, 4.52, 'N/A'),
#  ('EUCT', 'Consequential', 2017, 6, 0.17, 'N/A'),
#  ('KORL', 'Forced', 2017, 6, 0.28, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 6, 0.44, 'N/A'),
#  ('DNHR', 'Consequential', 2017, 6, 0.3, 'N/A'),
#  ('MELK', 'Scheduled (Planned)', 2017, 6, 2.38, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2017, 6, 0.2, 'N/A'),
#  ('PMC', 'Forced', 2017, 6, 0.62, 'Medium Risk'),
#  ('STHRNCRS', 'Forced', 2017, 6, 0.4, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 6, 0.17, 'Low Risk'),
#  ('ENRG', 'Forced', 2017, 6, 1.37, 'High Risk'),
#  ('KORL', 'Forced', 2017, 6, 4.56, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 5, 1.09, 'N/A'),
#  ('PUG', 'Scheduled (Planned)', 2016, 5, 0.27, 'N/A'),
#  ('KORL', 'Forced', 2016, 5, 0.5, 'Medium Risk'),
#  ('PMC', 'Forced', 2016, 5, 0.12, 'Low Risk'),
#  ('KORL', 'Forced', 2016, 5, 0.31, 'Low Risk'),
#  ('MUND', 'Scheduled (Planned)', 2016, 5, 6.38, 'N/A'),
#  ('ENRG', 'Consequential', 2016, 5, 0.28, 'N/A'),
#  ('PMC', 'Consequential', 2016, 5, 1.42, 'N/A'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 5, 3.44, 'N/A'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 5, 6.5, 'N/A'),
#  ('ENRG', 'Forced', 2016, 5, 1.29, 'High Risk'),
#  ('ENRG', 'Consequential', 2016, 5, 9.54, 'N/A'),
#  ('EUCT', 'Forced', 2016, 5, 2.99, 'High Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 5, 0.4, 'N/A'),
#  ('PJRH', 'Opportunistic Maintenance (Planned)', 2017, 5, 0.29, 'N/A'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 5, 0.93, 'N/A'),
#  ('PMC', 'Consequential', 2017, 5, 5.46, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 5, 0.4, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 5, 0.07, 'Low Risk'),
#  ('ENRG', 'Opportunistic Maintenance (Planned)', 2017, 5, 1.28, 'N/A'),
#  ('PJRH', 'Forced', 2017, 5, 0.25, 'Low Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 5, 2.13, 'N/A'),
#  ('AUXC', 'Forced', 2017, 5, 0.06, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 5, 0.42, 'Low Risk'),
#  ('WGUTD', 'Forced', 2017, 5, 0.12, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 4, 0.21, 'N/A'),
#  ('ENRG', 'Consequential', 2016, 4, 6.96, 'N/A'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 4, 0.13, 'N/A'),
#  ('STHRNCRS', 'Forced', 2016, 4, 0.57, 'Medium Risk'),
#  ('EUCT', 'Consequential', 2016, 4, 0.23, 'N/A'),
#  ('KORL', 'Opportunistic Maintenance (Planned)', 2016, 4, 9.45, 'N/A'),
#  ('PUG', 'Forced', 2016, 4, 0.29, 'Low Risk'),
#  ('PMC', 'Scheduled (Planned)', 2016, 4, 9.61, 'N/A'),
#  ('COLLGAR', 'Forced', 2016, 4, 0.08, 'Low Risk'),
#  ('PMC', 'Consequential', 2016, 4, 0.38, 'N/A'),
#  ('PUG', 'Forced', 2016, 4, 0.35, 'Low Risk'),
#  ('STHRNCRS', 'Consequential', 2016, 4, 0.27, 'N/A'),
#  ('COLLGAR', 'Forced', 2016, 4, 6.61, 'High Risk'),
#  ('PMC', 'Forced', 2016, 4, 0.17, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2016, 4, 0.52, 'Medium Risk'),
#  ('TRMOS', 'Forced', 2016, 4, 1.73, 'High Risk'),
#  ('PUG', 'Forced', 2017, 4, 0.14, 'Low Risk'),
#  ('TRMOS', 'Forced', 2017, 4, 0.39, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 4, 0.11, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 4, 0.37, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2017, 4, 1.29, 'N/A'),
#  ('PUG', 'Forced', 2017, 4, 5.02, 'High Risk'),
#  ('EUCT', 'Forced', 2017, 4, 0.15, 'Low Risk'),
#  ('MUND', 'Scheduled (Planned)', 2017, 4, 2.74, 'N/A'),
#  ('COLLGAR', 'Forced', 2017, 4, 0.01, 'Low Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 4, 9.4, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 4, 0.62, 'Medium Risk'),
#  ('ENRG', 'Forced', 2017, 4, 4.58, 'High Risk'),
#  ('MCG', 'Forced', 2017, 4, 0.06, 'Low Risk'),
#  ('PMC', 'Scheduled (Planned)', 2017, 4, 3.38, 'N/A'),
#  ('GW', 'Forced', 2017, 4, 0.31, 'Low Risk'),
#  ('MCG', 'Scheduled (Planned)', 2017, 4, 0.06, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2017, 4, 0.69, 'N/A'),
#  ('TRMOS', 'Forced', 2016, 3, 0.32, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 3, 1.35, 'N/A'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 3, 0.28, 'N/A'),
#  ('PUG', 'Scheduled (Planned)', 2016, 3, 0.24, 'N/A'),
#  ('STHRNCRS', 'Forced', 2016, 3, 0.38, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 3, 0.12, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2016, 3, 0.96, 'N/A'),
#  ('WGUTD', 'Consequential', 2016, 3, 0.65, 'N/A'),
#  ('KORL', 'Forced', 2016, 3, 2.01, 'High Risk'),
#  ('PMC', 'Consequential', 2016, 3, 0.33, 'N/A'),
#  ('COLLGAR', 'Forced', 2016, 3, 0.02, 'Low Risk'),
#  ('KORL', 'Forced', 2016, 3, 0.22, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 3, 7.22, 'N/A'),
#  ('TRMOS', 'Forced', 2016, 3, 0.31, 'Low Risk'),
#  ('KORL', 'Scheduled (Planned)', 2016, 3, 18.03, 'N/A'),
#  ('PUG', 'Scheduled (Planned)', 2016, 3, 0.16, 'N/A'),
#  ('TRMOS', 'Forced', 2016, 3, 0.17, 'Low Risk'),
#  ('WGUTD', 'Consequential', 2016, 3, 0.02, 'N/A'),
#  ('TRMOS', 'Forced', 2017, 3, 0.26, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 3, 0.68, 'Medium Risk'),
#  ('AUXC', 'Forced', 2017, 3, 0.99, 'Medium Risk'),
#  ('MUND', 'Forced', 2017, 3, 0.01, 'Low Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 3, 8.2, 'N/A'),
#  ('MUND', 'Forced', 2017, 3, 0.02, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 3, 0.63, 'Medium Risk'),
#  ('EUCT', 'Consequential', 2017, 3, 0.12, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 3, 0.71, 'Medium Risk'),
#  ('TSLA_MGT', 'Consequential', 2017, 3, 1.18, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 3, 0.15, 'Low Risk'),
#  ('WGUTD', 'Forced', 2017, 3, 8.98, 'High Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 2, 1.72, 'N/A'),
#  ('PUG', 'Scheduled (Planned)', 2016, 2, 0.48, 'N/A'),
#  ('MCG', 'Consequential', 2016, 2, 0.26, 'N/A'),
#  ('STHRNCRS', 'Consequential', 2016, 2, 0.42, 'N/A'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2016, 2, 5.18, 'N/A'),
#  ('PUG', 'Opportunistic Maintenance (Planned)', 2016, 2, 0.1, 'N/A'),
#  ('STHRNCRS', 'Consequential', 2016, 2, 0.53, 'N/A'),
#  ('ENRG', 'Scheduled (Planned)', 2016, 2, 2.48, 'N/A'),
#  ('STHRNCRS', 'Forced', 2016, 2, 0.38, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 2, 0.73, 'N/A'),
#  ('TRMOS', 'Forced', 2016, 2, 0.27, 'Low Risk'),
#  ('DNHR', 'Consequential', 2016, 2, 0.18, 'N/A'),
#  ('PUG', 'Forced', 2017, 2, 0.54, 'Medium Risk'),
#  ('DNHR', 'Consequential', 2017, 2, 0.26, 'N/A'),
#  ('EUCT', 'Consequential', 2017, 2, 1.31, 'N/A'),
#  ('MCG', 'Consequential', 2017, 2, 0.23, 'N/A'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 2, 0.06, 'N/A'),
#  ('PUG', 'Forced', 2017, 2, 0.18, 'Low Risk'),
#  ('AUXC', 'Forced', 2017, 2, 0.0, 'Low Risk'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 2, 2.07, 'N/A'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2017, 2, 0.28, 'N/A'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 2, 5.34, 'N/A'),
#  ('PMC', 'Forced', 2017, 2, 0.0, 'Low Risk'),
#  ('ENRG', 'Scheduled (Planned)', 2017, 2, 1.02, 'N/A'),
#  ('EUCT', 'Consequential', 2017, 2, 0.02, 'N/A'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 1, 1.56, 'N/A'),
#  ('DNHR', 'Consequential', 2016, 1, 0.44, 'N/A'),
#  ('MUND', 'Forced', 2016, 1, 0.73, 'Medium Risk'),
#  ('COLLGAR', 'Forced', 2016, 1, 0.06, 'Low Risk'),
#  ('TRMOS', 'Forced', 2016, 1, 0.17, 'Low Risk'),
#  ('TSLA_MGT', 'Scheduled (Planned)', 2016, 1, 1.42, 'N/A'),
#  ('DNHR', 'Consequential', 2016, 1, 0.08, 'N/A'),
#  ('MCG', 'Scheduled (Planned)', 2016, 1, 1.42, 'N/A'),
#  ('MUND', 'Scheduled (Planned)', 2016, 1, 8.92, 'N/A'),
#  ('STHRNCRS', 'Consequential', 2016, 1, 0.04, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2016, 1, 0.02, 'N/A'),
#  ('WGUTD', 'Consequential', 2016, 1, 0.23, 'N/A'),
#  ('DNHR', 'Consequential', 2016, 1, 0.35, 'N/A'),
#  ('EUCT', 'Forced', 2016, 1, 9.81, 'High Risk'),
#  ('COLLGAR', 'Scheduled (Planned)', 2016, 1, 24.04, 'N/A'),
#  ('DNHR', 'Forced', 2016, 1, 0.4, 'Low Risk'),
#  ('EUCT', 'Forced', 2016, 1, 19.29, 'High Risk'),
#  ('PJRH', 'Forced', 2016, 1, 0.31, 'Low Risk'),
#  ('TSLA_MGT', 'Consequential', 2016, 1, 0.02, 'N/A'),
#  ('EUCT', 'Forced', 2016, 1, 15.02, 'High Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2016, 1, 0.21, 'N/A'),
#  ('STHRNCRS', 'Scheduled (Planned)', 2016, 1, 0.23, 'N/A'),
#  ('MCG', 'Forced', 2016, 1, 0.79, 'Medium Risk'),
#  ('DNHR', 'Consequential', 2016, 1, 0.06, 'N/A'),
#  ('MUND', 'Forced', 2016, 1, 0.06, 'Low Risk'),
#  ('COLLGAR', 'Forced', 2017, 1, 0.0, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 1, 0.13, 'N/A'),
#  ('KORL', 'Forced', 2017, 1, 0.17, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.02, 'Low Risk'),
#  ('WGUTD', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.0, 'N/A'),
#  ('COLLGAR', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.25, 'N/A'),
#  ('PMC', 'Scheduled (Planned)', 2017, 1, 0.1, 'N/A'),
#  ('DNHR', 'Consequential', 2017, 1, 0.33, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.65, 'Medium Risk'),
#  ('WGUTD', 'Consequential', 2017, 1, 0.04, 'N/A'),
#  ('DNHR', 'Consequential', 2017, 1, 0.33, 'N/A'),
#  ('MCG', 'Forced', 2017, 1, 0.17, 'Low Risk'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.33, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.63, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.33, 'Low Risk'),
#  ('MUND', 'Opportunistic Maintenance (Planned)', 2017, 1, 0.08, 'N/A'),
#  ('TSLA_MGT', 'Consequential', 2017, 1, 0.31, 'N/A'),
#  ('DNHR', 'Consequential', 2017, 1, 0.13, 'N/A'),
#  ('STHRNCRS', 'Forced', 2017, 1, 0.31, 'Low Risk'),
#  ('DNHR', 'Consequential', 2017, 1, 0.17, 'N/A')]

# %% [markdown]
# <h3 style="color:#D4AF37"> ⚡ Part II. Energy Losses & Market Reliability ⚡ </h3>

# %% [markdown]
# When an energy provider provides energy to the market, they are making a commitment to the market and saying; “We will supply X amount of energy to the market under a contractual obligation.” However, in a situation where the outages are Forced, the energy provider intended to provide energy but are unable to provide energy and are forced offline. <b style="color:Maroon">If many energy providers are forced offline at the same time it could cause an energy security risk that AEMR needs to mitigate. </b>
#
# To ensure this doesn’t happen, the AEMR is interested in exploring the following questions:
#
# <li> Of the outage types in 2016 and 2017, what percent were Forced Outage(s)?
# <li> What was the average duration for a forced outage during both 2016 and 2017? Have we seen an increase in the average duration of forced outages?
# <li> Which energy providers tended to have the largest number of forced outages?
#
# <p>

# %% [markdown]
# <h3 style="color:#D4AF37"> 6. </h3>

# %% [markdown]
# <b> We will write a SQL Statement to calculate the proportion of Forced Outages that have occurred over the 2016 - 2017 Period.
# </b>

# %%
# %%sql
# SELECT
# Year,
# COUNT(*) AS Total_Number_Outage,
# SUM(CASE WHEN Outage_Reason = 'Forced' THen 1 Else 0 END) AS Total_Number_Forced_Outage_Events,
# ROUND(SUM(CASE WHEN Outage_Reason = 'Forced' THen 1 Else 0 END)*1.0/COUNT (*)*100,2) AS Pct_Outage_Forced
# -- *1.0: to make it a float
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Year
# ;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(2016, 1931, 1264, 65.46), (2017, 2171, 1622, 74.71)]

# %% [markdown]
# It's clear to see now that `Forced Outages` are problematic for us. Not only are they the only outage type that generates financial losses as the Outage is unplanned, it seems there is a number of Energy Participants who have been having a significantly high number of Outages.
#
#
# Let's break our analysis down into Macro and Micro Analysis.
# The total gives us the Overall Duration a participant is offline / has lost energy, however, it doesn't tell us how *frequently* this occurs. In other words, if we have one or two very big outages, it might contribute to very large totals.
#
# However, perhaps an <b> average </b> can help us identify how big these Outages might really be, spread across the year.

# %% [markdown]
# <h3 style="color:#D4AF37"> 7. </h3>

# %% [markdown]
# <b> This SQL Statement will calculate the `Total Number of Outages`, `Total Duration In Days`and `Total Energy Lost` of all valid `Outages` for each `participant code` and `facility_code`, sorted by `Total Energy Lost` in descending order and Ordered by the YEAR Category.

# %%
# %%sql
# SELECT
# COUNT(*) AS Total_Number_Outages,
# ROUND(SUM(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2)Total_Duration_In_Days,
# ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost,
# Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved'
# GROUP BY Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year -- Group by non-aggrigate ,
#
# ORDER BY Total_Energy_Lost DESC, Year DESC;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(490, 33.65, 21639.55, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (227, 240.69, 19326.56, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (317, 120.6, 15751.38, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (157, 129.6, 13771.07, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (208, 15.06, 10696.28, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (177, 404.15, 10285.4, 'Forced', 'MELK', 'MELK_G7', 2017),
#  (85, 392.25, 9668.79, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2016),
#  (69, 34.06, 9093.09, 'Forced', 'PMC', 'PMC_AG', 2016),
#  (70, 482.58, 7499.28, 'Scheduled (Planned)', 'MELK', 'MELK_G7', 2017),
#  (46, 87.02, 6964.8, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (45, 199.4, 6450.0, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (45, 65.4, 5941.25, 'Scheduled (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (81, 98.79, 5881.52, 'Forced', 'PJRH', 'PJRH_GT11', 2016),
#  (40, 1.56, 5648.44, 'Forced', 'PMC', 'PMC_AG', 2017),
#  (172, 71.9, 5016.67, 'Forced', 'TRMOS', 'TIWEST_COG1', 2017),
#  (72, 60.13, 4839.28, 'Forced', 'PJRH', 'PJRH_GT11', 2017),
#  (27, 51.4, 4839.0, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2016),
#  (76, 91.79, 4679.68, 'Forced', 'KORL', 'KORL_GT3', 2017),
#  (29, 32.33, 4320.86, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (135, 33.4, 4112.1, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (53, 20.0, 4040.32, 'Forced', 'KORL', 'KORL_GT3', 2016),
#  (41, 5.31, 3925.55, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (26, 68.9, 3812.42, 'Scheduled (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (39, 9.17, 3100.95, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (20, 6.21, 2951.0, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (24, 17.0, 2877.04, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2016),
#  (45, 62.1, 2787.06, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (206, 16.04, 2734.14, 'Forced', 'AUXC', 'AUXC_WGP', 2016),
#  (42, 8.88, 2553.24, 'Consequential', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (38, 89.9, 2445.0, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (23, 4.21, 2178.95, 'Opportunistic Maintenance (Planned)', 'PJRH', 'PJRH_GT11', 2016),
#  (12, 51.38, 2139.87, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (35, 91.35, 2110.01, 'Scheduled (Planned)', 'PJRH', 'PJRH_GT11', 2017),
#  (120, 2.1, 1768.76, 'Forced', 'AUXC', 'AUXC_WGP', 2017),
#  (20, 139.25, 1685.6, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (8, 28.15, 1672.66, 'Consequential', 'PMC', 'PMC_AG', 2017),
#  (12, 20.35, 1639.2, 'Scheduled (Planned)', 'PMC', 'PMC_AG', 2017),
#  (9, 57.27, 1632.78, 'Scheduled (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (7, 5.35, 1524.82, 'Consequential', 'MELK', 'MELK_G7', 2016),
#  (13, 3.67, 1423.53, 'Opportunistic Maintenance (Planned)', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (12, 7.15, 1374.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (16, 10.44, 1339.7, 'Opportunistic Maintenance (Planned)', 'MELK', 'MELK_G7', 2017),
#  (16, 23.56, 1334.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (16, 54.1, 1326.6, 'Scheduled (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (65, 12.63, 1232.43, 'Forced', 'TRMOS', 'TIWEST_COG1', 2016),
#  (21, 47.04, 1182.8, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (14, 3.04, 1172.05, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2016),
#  (11, 24.73, 1160.0, 'Scheduled (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (5, 1.17, 926.0, 'Consequential', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (10, 2.42, 842.8, 'Opportunistic Maintenance (Planned)', 'KORL', 'KORL_GT3', 2017),
#  (20, 3.6, 832.72, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (24, 22.17, 815.47, 'Forced', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (5, 1.65, 763.96, 'Opportunistic Maintenance (Planned)', 'COLLGAR', 'COLLGAR_WF1', 2017),
#  (28, 27.75, 678.4, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (18, 63.46, 664.0, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (10, 2.81, 643.0, 'Consequential', 'PMC', 'PMC_AG', 2016),
#  (7, 1.48, 580.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2016),
#  (12, 3.4, 563.33, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (3, 0.98, 523.0, 'Opportunistic Maintenance (Planned)', 'AURICON', 'AURICON_PNJ_U1', 2016),
#  (37, 183.58, 516.92, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (6, 13.42, 505.95, 'Consequential', 'KORL', 'KORL_GT3', 2017),
#  (23, 45.25, 448.8, 'Scheduled (Planned)', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (29, 140.6, 445.6, 'Scheduled (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (15, 2.85, 398.58, 'Forced', 'MUND', 'MUNDARING_GT1', 2017),
#  (3, 0.71, 348.0, 'Opportunistic Maintenance (Planned)', 'PUG', 'PERTHENERGY_KORL_GT1', 2017),
#  (9, 1.9, 335.86, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (1, 0.25, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2017),
#  (1, 0.08, 335.0, 'Opportunistic Maintenance (Planned)', 'PMC', 'PMC_AG', 2016),
#  (14, 9.46, 322.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (13, 4.29, 299.0, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (13, 8.04, 299.0, 'Scheduled (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (30, 13.21, 297.0, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (18, 4.65, 292.7, 'Forced', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (17, 6.96, 290.4, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2016),
#  (7, 11.9, 262.46, 'Scheduled (Planned)', 'MUND', 'MUNDARING_GT1', 2017),
#  (8, 1.21, 248.0, 'Opportunistic Maintenance (Planned)', 'MUND', 'MUNDARING_GT1', 2016),
#  (23, 7.73, 227.7, 'Consequential', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (14, 4.52, 222.3, 'Consequential', 'EUCT', 'GRASMERE_WF1', 2017),
#  (8, 27.54, 221.29, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (4, 0.23, 220.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (9, 1.94, 207.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2016),
#  (6, 11.96, 198.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (7, 1.85, 191.86, 'Forced', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (4, 1.23, 169.9, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2017),
#  (4, 9.23, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2017),
#  (5, 7.08, 168.4, 'Scheduled (Planned)', 'TRMOS', 'TIWEST_COG1', 2016),
#  (15, 8.48, 161.4, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (2, 0.5, 160.0, 'Forced', 'TSLA_MGT', 'TESLA_PICTON_G1', 2016),
#  (4, 1.48, 147.2, 'Forced', 'MUND', 'MUNDARING_GT1', 2016),
#  (2, 0.52, 110.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (2, 0.46, 94.0, 'Consequential', 'MCG', 'MWF_MUMBIDA_WF1', 2017),
#  (4, 0.96, 89.29, 'Consequential', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (4, 1.9, 87.0, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2016),
#  (2, 0.1, 72.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (3, 0.1, 64.8, 'Forced', 'EUCT', 'GRASMERE_WF1', 2017),
#  (11, 64.9, 64.8, 'Forced', 'EUCT', 'GRASMERE_WF1', 2016),
#  (7, 1.87, 63.8, 'Consequential', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (1, 0.79, 55.0, 'Forced', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (1, 1.42, 55.0, 'Scheduled (Planned)', 'MCG', 'MWF_MUMBIDA_WF1', 2016),
#  (2, 0.04, 54.0, 'Forced', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (2, 2.5, 50.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2016),
#  (2, 0.52, 46.0, 'Consequential', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (1, 0.04, 36.0, 'Consequential', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (1, 10.58, 36.0, 'Scheduled (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2017),
#  (1, 0.6, 36.0, 'Opportunistic Maintenance (Planned)', 'WGUTD', 'WEST_KALGOORLIE_GT2', 2016),
#  (1, 0.1, 26.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2017),
#  (1, 2.88, 26.0, 'Scheduled (Planned)', 'AUXC', 'AUXC_WGP', 2017),
#  (1, 0.96, 25.0, 'Consequential', 'AUXC', 'AUXC_WGP', 2016),
#  (3, 1.04, 24.1, 'Opportunistic Maintenance (Planned)', 'ENRG', 'ENRG_KALGOORLIE_GT3', 2017),
#  (1, 0.06, 23.0, 'Opportunistic Maintenance (Planned)', 'STHRNCRS', 'STHRNCRS_EG', 2017),
#  (12, 2.9, 17.28, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (11, 3.12, 15.84, 'Consequential', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (1, 0.48, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2017),
#  (1, 0.4, 1.44, 'Forced', 'DNHR', 'DNHR_DENMARK_WF1', 2016),
#  (1, 0.06, 0.0, 'Opportunistic Maintenance (Planned)', 'TRMOS', 'TIWEST_COG1', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> 8. </h3>

# %% [markdown]
# <b> This SQL Statement will calculate the `Average Duration In Days`and `Average Energy Lost` of all valid `FORCED OUTAGES` for each `participant code` and `facility_code` sorted by `Average Energy Lost` in descending order and Ordered by the YEAR Category.

# %%
# %%sql
# SELECT
# ROUND(AVG(ABS(JULIANDAY(End_Time) - JULIANDAY(Start_Time))),2) AS Avg_Duration_In_Days,
# ROUND(AVG(Energy_Lost_MW),2) AS Avg_Energy_Lost,
# Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved' AND Outage_Reason = 'Forced'
# GROUP BY Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year -- Group by non-aggrigate ,
#
# ORDER BY Avg_Energy_Lost DESC, Year DESC
# LIMIT 5;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(1.11, 149.0, 'Forced', 'COLLGAR', 'COLLGAR_WF1', 2016),
#  (0.04, 141.21, 'Forced', 'PMC', 'PMC_AG', 2017),
#  (0.49, 131.78, 'Forced', 'PMC', 'PMC_AG', 2016),
#  (0.83, 87.71, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (1.06, 85.14, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017)]

# %% [markdown]
# <h3 style="color:#D4AF37"> 9. </h3>

# %% [markdown]
# <b> This SQL Statement will calculate the `Average Energy Lost` and `Total Energy Lost` for each `Facility Code` and `Participant Code` across both the 2016 and 2017 periods when the `Outage_Reason` is set to Forced. Upon completion of this, calculate the <u> percentage </u> of energy lost due to forced outages for each `Facility_Code`. Please ORDER the query by `Total Energy Lost` from 2016 to 2017.
#
# AURICON has contributed the most to the Energy Lost due to Forced Outages.

# %%
# %%sql
# SELECT
# ROUND(AVG(Energy_Lost_MW),2) AS Avg_Energy_Lost,
# ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost,
# ROUND((SUM(Energy_Lost_MW)/ (
#     SELECT SUM(Energy_Lost_MW)
#     FROM AEMR_Outage_Table
#     WHERE Status = 'Approved' AND Outage_Reason = 'Forced'
# ))*100,2) AS Pct_Energy_Loss,
#
# Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year
# FROM AEMR_Outage_Table
# WHERE Status = 'Approved' AND Outage_Reason = 'Forced'
# GROUP BY Outage_Reason,
# Participant_Code,
# Facility_Code,
# Year
#
# ORDER BY Total_Energy_Lost DESC, Year DESC
# LIMIT 5;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [(44.16, 21639.55, 14.21, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2017),
#  (85.14, 19326.56, 12.69, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2017),
#  (49.69, 15751.38, 10.34, 'Forced', 'GW', 'BW1_GREENWATERS_G2', 2016),
#  (87.71, 13771.07, 9.04, 'Forced', 'MELK', 'MELK_G7', 2016),
#  (51.42, 10696.28, 7.02, 'Forced', 'AURICON', 'AURICON_PNJ_U1', 2016)]

# %% [markdown]
# <h3 style="color:#D4AF37"> 10. </h3>

# %% [markdown]
# <b>Having identified the top 3 participants by Total Energy Loss being `GW`, `MELK` and `Auricon`; We will write a SQL Statement calculating the `Total_Energy_Lost` each of these three `Participant_Codes` and the `Facility_Code`. Additionally, identify the `Description_Of_Outage` associated with the highest `Total_Energy_Lost` for each of the `Participant_Codes` and `Facility_Code` for each of the three participants.
#
# Lastly, we will calculate the percentage of Energy Loss, attributed to these reasons.</b>

# %%
# %%sql
# SELECT *
# FROM (
# SELECT
# Participant_Code,
# Facility_Code,
# Description_Of_Outage,
#
# ROUND(SUM(Energy_Lost_MW),2) AS Total_Energy_Lost,
#
# ROUND((SUM(Energy_Lost_MW)/ (
#     SELECT SUM(Energy_Lost_MW)
#     FROM AEMR_Outage_Table
#     WHERE Status = 'Approved' AND Outage_Reason = 'Forced'
# ))*100,2) AS Pct_Energy_Loss,
#
# RANK() OVER (PARTITION BY Participant_Code, Facility_Code ORDER BY SUM(Energy_Lost_MW) DESC) AS Ranking
#
#
# FROM AEMR_Outage_Table
# WHERE Participant_Code IN ('GW', 'MELK', 'AURICON') AND Status = 'Approved' AND Outage_Reason = 'Forced'
# GROUP BY Participant_Code,
# Facility_Code,
# Description_Of_Outage
#
# ORDER BY Participant_Code, Total_Energy_Lost DESC)
# WHERE Ranking = 1;
# Out:
#  * sqlite:///AEMR.db
# Done.
# [('AURICON', 'AURICON_PNJ_U1', 'Full unit trip', 6033.87, 3.96, 1),
#  ('GW', 'BW1_GREENWATERS_G2', 'Operational Issues caused real time forced outage.', 28687.54, 18.84, 1),
#  ('MELK', 'MELK_G7', 'Safety Issues', 1100.0, 0.72, 1)]
